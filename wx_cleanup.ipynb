# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
site_name = 'Freeman'
site_raw = pd.read_csv(f'C:/Users/RDCRLSMC/Desktop/Freeman_Daily.dat',
                       on_bad_lines='skip',
                       delimiter=',',
                       low_memory=False,
                       skiprows=[0, 2, 3])

#site_raw.to_csv(f'C:/Users/RDCRLSMC/Desktop/{site_name}_very_dirty.csv',)
print(site_raw.columns)
# Out:
# Index(['TIMESTAMP', 'RECORD', 'PTemp_C', 'BattV_Min', 'Temp_C_Avg',
#        'BV_BP_Avg', 'BV_Temp_Avg', 'BV_BP_Max', 'BV_BP_Min', 'AirTC_Avg',
#        ...
#        'DTC_Avg(28)', 'DTC_Avg(29)', 'DTC_Avg(30)', 'DTC_Avg(31)',
#        'DTC_Avg(32)', 'DTC_Avg(33)', 'DTC_Avg(34)', 'DTC_Avg(35)',
#        'DTC_Avg(36)', 'DTC_Avg(37)'],
#       dtype='object', length=113)
