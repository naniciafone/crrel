# %%
import laspy

# %%
#Ralipod filepaths
rpod_pc = "C:/Users/RDCRLSMC/Desktop/20241107_Camas/09_EXPORT/merge.laz"
rpod_dtm = "C:/Users/RDCRLSMC/Desktop/20241107_Camas/09_EXPORT/dtm.tif"

#USGS filepaths 
FEMA_pc = "C:/Users/RDCRLSMC/Desktop/camas_3dep/laz_tiles/FEMA/reproject.laz"
FEMA_dtm = "C:/Users/RDCRLSMC/Desktop/camas_3dep/laz_tiles/FEMA/FEMA_WGS.tif"

#SID
SID_pc = "C:/Users/RDCRLSMC/Desktop/camas_3dep/laz_tiles/SouthernID_clip/SouthernID_merge.laz"
SID_dtm = "C:/Users/RDCRLSMC/Desktop/camas_3dep/laz_tiles/SouthernID_clip/SID_WGS.tif"

pc_list = [rpod_pc, FEMA_pc, SID_pc]
dtm_list = [rpod_dtm, FEMA_dtm, SID_dtm]

# %%
#Check that CRS data is the same for all LAZ

for pc in pc_list:
    with laspy.open(pc, "r") as las:
        crs = las.header.crs
        
    print(crs)
