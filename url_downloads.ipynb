# %%
from concurrent.futures import ThreadPoolExecutor
import requests

# %%
def download_file(url):
    response = requests.get(url)
    if "content-disposition" in response.headers:
        content_disposition = response.headers["content-disposition"]
        filename = content_disposition.split("filename=")[1]
    else:
        filename = url.split("/")[-1]
    with open(filename, mode="wb") as file:
        file.write(response.content)
    print(f"Downloaded file {filename}")

# %%
url_list = "C:/Users/RDCRLSMC/Downloads/downloadlist.txt"

# %%
# Open and read the file
with open(url_list, 'r') as file:
    urls = [line.strip() for line in file if line.strip()]  # Read and strip each line

# Output the list of URLs
print("Loaded URLs:")
for url in urls:
    print(url)
# Out:
# Loaded URLs:
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_SouthernID_2018_D19/TIFF/USGS_1M_11_x63y479_ID_SouthernID_2018_D19.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_SouthernID_2018_D19/TIFF/USGS_1M_11_x63y480_ID_SouthernID_2018_D19.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_SouthernID_2018_D19/TIFF/USGS_1M_11_x64y479_ID_SouthernID_2018_D19.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_SouthernID_2018_D19/TIFF/USGS_1M_11_x64y480_ID_SouthernID_2018_D19.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_SouthernID_2018_D19/TIFF/USGS_1M_11_x65y479_ID_SouthernID_2018_D19.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_SouthernID_2018_D19/TIFF/USGS_1M_11_x65y480_ID_SouthernID_2018_D19.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_SouthernID_2018_D19/TIFF/USGS_1M_11_x65y481_ID_SouthernID_2018_D19.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_SouthernID_2018_D19/TIFF/USGS_1M_11_x66y479_ID_SouthernID_2018_D19.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_SouthernID_2018_D19/TIFF/USGS_1M_11_x66y480_ID_SouthernID_2018_D19.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_FEMAHQ_2018/TIFF/USGS_one_meter_x63y479_ID_FEMAHQ_2018.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_FEMAHQ_2018/TIFF/USGS_one_meter_x63y480_ID_FEMAHQ_2018.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_FEMAHQ_2018/TIFF/USGS_one_meter_x64y480_ID_FEMAHQ_2018.tif
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1m/Projects/ID_FEMAHQ_2018/TIFF/USGS_one_meter_x65y481_ID_FEMAHQ_2018.tif

# %%
for url in urls:
    download_file(url)
# Out:
# Downloaded file USGS_1M_11_x63y479_ID_SouthernID_2018_D19.tif
# Downloaded file USGS_1M_11_x63y480_ID_SouthernID_2018_D19.tif
# Downloaded file USGS_1M_11_x64y479_ID_SouthernID_2018_D19.tif
# Downloaded file USGS_1M_11_x64y480_ID_SouthernID_2018_D19.tif
# Downloaded file USGS_1M_11_x65y479_ID_SouthernID_2018_D19.tif
# Downloaded file USGS_1M_11_x65y480_ID_SouthernID_2018_D19.tif
# Downloaded file USGS_1M_11_x65y481_ID_SouthernID_2018_D19.tif
# Downloaded file USGS_1M_11_x66y479_ID_SouthernID_2018_D19.tif
# Downloaded file USGS_1M_11_x66y480_ID_SouthernID_2018_D19.tif
# Downloaded file USGS_one_meter_x63y479_ID_FEMAHQ_2018.tif
# Downloaded file USGS_one_meter_x63y480_ID_FEMAHQ_2018.tif
# Downloaded file USGS_one_meter_x64y480_ID_FEMAHQ_2018.tif
# Downloaded file USGS_one_meter_x65y481_ID_FEMAHQ_2018.tif
